# %%
#!/usr/bin/env python3
import csv
import sys
import matplotlib.pyplot as plt
import pandas as pd
import os
import os.path
from matplotlib import rcParams
rcParams["font.family"] = "sans-serif"
rcParams["font.sans-serif"] = ["Meiryo"]

out_dir = "out/"
os.makedirs(out_dir, exist_ok=True)

# %%
# import csv files
import_files = ['./import/0000.csv',
               ]

# %%
#プロットピッチと時間軸名を入力
plt_pitch = 3600
dictionary = {3600:"1h",
              1800:"30m",
              60:"1m",
              1:"1s",
              }

plt_name = dictionary[plt_pitch]
print(plt_name)
# Out:
# 1h

# %%
col_name = range(1,12,1)
df0 = pd.read_csv(import_files[0], names = col_name, encoding="shift-jis", delimiter=",", dtype="object")
df0
# Out:
#                    1    2                 3    4     5         6    7    8   \
# 0        #BeginHeader  NaN                48  NaN   NaN       NaN  NaN  NaN
# 1         #FormatType  NaN  TR-H Memory Data  NaN   NaN       NaN  NaN  NaN
# 2      #FormatVersion  NaN          R2.00.00  NaN   NaN       NaN  NaN  NaN
# 3                 機器名  NaN               NaN  NaN   NaN       NaN  NaN  NaN
# 4                タイトル  NaN               NaN  NaN   NaN       NaN  NaN  NaN
# ...               ...  ...               ...  ...   ...       ...  ...  ...
# 83085         対象チャンネル  NaN                現象   種類    日時    日時(ms)    値   単位
# 83086       #EndAlarm  NaN               NaN  NaN   NaN       NaN  NaN  NaN
# 83087   #BeginComment  NaN                 3  NaN   NaN       NaN  NaN  NaN
# 83088        コメントタイトル  NaN          手書きファイル名   種別  作成日時  作成日時(ms)  NaN  NaN
# 83089     #EndComment  NaN               NaN  NaN   NaN       NaN  NaN  NaN
#
#         9    10   11
# 0      NaN  NaN  NaN
# 1      NaN  NaN  NaN
# 2      NaN  NaN  NaN
# 3      NaN  NaN  NaN
# 4      NaN  NaN  NaN
# ...    ...  ...  ...
# 83085  NaN  NaN  NaN
# 83086  NaN  NaN  NaN
# 83087  NaN  NaN  NaN
# 83088  NaN  NaN  NaN
# 83089  NaN  NaN  NaN
#
# [83090 rows x 11 columns]

# %%
# plt_num = int(df0.iloc[12,2])
# print("plt_num = ",plt_num)

# %%
df_data = df0.loc[df0[1] == 'データ数']
print("plt_num = ",df_data.iloc[0,2])
# Out:
# plt_num =  83036

# %%
header_num = int(df0.iloc[0,2]) - 7
_df0 = df0[header_num:]
_df0 = _df0.drop([1,2], axis=1)
_df0 = _df0.dropna(how='all', axis=1)
_df0 = _df0.dropna(how='any')
_df0 = _df0[1:].astype(float)
_df0
